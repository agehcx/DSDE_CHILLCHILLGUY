# %%
# %pip install pandas
# %pip install scikit-learn
# %pip install numpy
# %pip install gensim
# %pip install scipy
# %pip install xgboost
# %pip install seaborn
# %pip install pyspark
# %pip install autogluon
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['HADOOP_HOME'] = r"C:\hadoop"

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Test") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[17], line 5
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("Test") \
# ----> 5     .getOrCreate()
#
# File c:\Python312\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
#     500 session = SparkSession(sc, options=self._options)
#
# File c:\Python312\Lib\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Cassandra Example") \
    .config("spark.cassandra.connection.host", "127.0.0.1") \
    .config("spark.cassandra.connection.port", "9042") \
    .config("spark.jars.packages", "com.datastax.spark:spark-cassandra-connector_2.12:3.4.0") \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[18], line 8
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("Cassandra Example") \
#       5     .config("spark.cassandra.connection.host", "127.0.0.1") \
#       6     .config("spark.cassandra.connection.port", "9042") \
#       7     .config("spark.jars.packages", "com.datastax.spark:spark-cassandra-connector_2.12:3.4.0") \
# ----> 8     .getOrCreate()
#
# File c:\Python312\Lib\site-packages\pyspark\sql\session.py:497, in SparkSession.Builder.getOrCreate(self)
#     495     sparkConf.set(key, value)
#     496 # This SparkContext may be an existing one.
# --> 497 sc = SparkContext.getOrCreate(sparkConf)
#     498 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499 # by all sessions.
# ...

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
from sklearn.metrics import silhouette_score
import gensim.downloader as api
from scipy.sparse import hstack
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load data from Cassandra
df = spark.read \
    .format("org.apache.spark.sql.cassandra") \
    .options(table="data", keyspace="space") \
    .load()

df = df.toPandas()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Load data from Cassandra
# ----> 2 df = spark.read \
#       3     .format("org.apache.spark.sql.cassandra") \
#       4     .options(table="data", keyspace="space") \
#       5     .load()
#       7 df = df.toPandas()
#
# NameError: name 'spark' is not defined

# %%
# Load additional CSV data
direct_df = pd.read_csv("../MergedData.csv")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16080\1266444914.py:2: DtypeWarning: Columns (162,163,165,221,240,242,245,246,247,248,250,251,252,258,260,263,264,267,269,273,275,276,277,278,279,280,282,283,284,285,286,288,289,290,291,292,293,294,295,296,297,298,299,300,301) have mixed types. Specify dtype option on import or set low_memory=False.
#   direct_df = pd.read_csv("../MergedData.csv")

# %%
# Map countries to continents
country_to_continent = { ... }
def map_country_to_continent(countries):
    if pd.isna(countries):
        return 'Unknown'
    continents = [country_to_continent.get(country.strip(), 'Unknown') for country in countries.split(',')]
    return continents

# %%
df['continent'] = df['AffiliationCountry'].apply(map_country_to_continent)
continent_counts = df['continent'].apply(lambda x: {c: x.count(c) for c in set(x)})
continent_df = pd.DataFrame(continent_counts.tolist()).fillna(0).astype(int)
result_df = pd.concat([df, continent_df], axis=1).drop(columns=['continent', 'AffiliationCountry'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df['continent'] = df['AffiliationCountry'].apply(map_country_to_continent)
#       2 continent_counts = df['continent'].apply(lambda x: {c: x.count(c) for c in set(x)})
#       3 continent_df = pd.DataFrame(continent_counts.tolist()).fillna(0).astype(int)
#
# NameError: name 'df' is not defined

# %%
# Sample and preprocess data
result_df = result_df.sample(n=2000, random_state=42)
result_df.to_csv('sampled_result_df.csv', index=False)

Q1 = result_df['CitedByCount'].quantile(0.25)
Q3 = result_df['CitedByCount'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
filtered_df = result_df[(result_df['CitedByCount'] >= lower_bound) & (result_df['CitedByCount'] <= upper_bound)]

filtered_df['CombinedText'] = filtered_df['AuthorKeywords'] + ' ' + filtered_df['Title'] + ' ' + filtered_df['PublicationName']
vectorizer = TfidfVectorizer(max_df=0.85, min_df=1, ngram_range=(1, 3))
X_text = vectorizer.fit_transform(filtered_df['CombinedText'].fillna(''))
X = pd.concat([filtered_df.reset_index(drop=True), pd.DataFrame(X_text.toarray(), columns=vectorizer.get_feature_names_out())], axis=1).drop(columns=['AuthorKeywords', 'Title', 'PublicationName', 'CombinedText', 'CitedByCount'])

X_train, X_test, y_train, y_test = train_test_split(X, filtered_df['CitedByCount'], test_size=0.2, random_state=42)
model = XGBRegressor(n_estimators=100, random_state=42).fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'R^2 Score: {r2_score(y_test, y_pred)}')

# %%
# AutoGluon
from autogluon.tabular import TabularPredictor
predictor = TabularPredictor(label='CitedByCount', problem_type='regression', eval_metric='mean_squared_error').fit(filtered_df)
leaderboard = predictor.leaderboard()
print(leaderboard)
